# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('MODIS_Aqua_STATES_2018.xlsx')

# %%
df.head()
# Out:
#         Unnamed: 0      Unnamed: 1
# 0       Row Labels  Count of State
# 1          Alabama            2109
# 2          Arizona            1310
# 3         Arkansas            1660
# 4  Baja California             142

# %%
Aquadf = df[df['SAT_SRC,C,1'] == 'A']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SAT_SRC,C,1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-78e44abe9ac0> in <module>
# ...

# %%
Aquadf.head()
# Out:
#     AREA,N,20,5  PERIMETER,N,20,5  FIRE_,N,11,0  FIRE_ID,N,11,0  LAT,N,13,3  \
# 1             0                 0             2          143041      49.455
# 3             0                 0             4          156898      49.454
# 4             0                 0             5          140750      49.454
# 6             0                 0             7          162038      49.453
# 13            0                 0            14          177985      49.450
#
#     LONG,N,13,3     DATE,D  JULIAN,N,3,0  GMT,N,4,0  TEMP,N,6,1  SPIX,N,6,1  \
# 1      -119.016 2018-08-13           225       2122       306.4         2.0
# 3      -118.350 2018-08-18           230       2001       312.9         2.3
# 4      -116.476 2018-08-12           224        933       307.7         1.4
# 6      -118.362 2018-08-20           232       1024       304.0         1.2
# 13     -118.349 2018-08-23           235       2019       322.3         1.4
#
# ...

# %%
Terradf = df[df['SAT_SRC,C,1'] == 'T']

# %%
Terradf.head()
# Out:
#    AREA,N,20,5  PERIMETER,N,20,5  FIRE_,N,11,0  FIRE_ID,N,11,0  LAT,N,13,3  \
# 0            0                 0             1          286339      49.456
# 2            0                 0             3          450729      49.455
# 5            0                 0             6          286338      49.454
# 7            0                 0             8          440365      49.453
# 8            0                 0             9          435749      49.452
#
#    LONG,N,13,3     DATE,D  JULIAN,N,3,0  GMT,N,4,0  TEMP,N,6,1  SPIX,N,6,1  \
# 0      -97.488 2018-05-10           130       1708       324.3         1.6
# 2     -115.999 2018-11-21           325        533       327.3         1.1
# 5      -97.466 2018-05-10           130       1703       310.6         1.6
# 7     -101.153 2018-10-20           293       1737       309.9         1.1
# 8     -118.697 2018-10-04           277       1916       304.7         1.2
#
#    TPIX,N,6,1 SRC,C,10 SAT_SRC,C,1  CONF,N,3,0  FRP,N,8,1
# ...

# %%
df.columns
# Out:
# Index(['AREA,N,20,5', 'PERIMETER,N,20,5', 'FIRE_,N,11,0', 'FIRE_ID,N,11,0',
#        'LAT,N,13,3', 'LONG,N,13,3', 'DATE,D', 'JULIAN,N,3,0', 'GMT,N,4,0',
#        'TEMP,N,6,1', 'SPIX,N,6,1', 'TPIX,N,6,1', 'SRC,C,10', 'SAT_SRC,C,1',
#        'CONF,N,3,0', 'FRP,N,8,1'],
#       dtype='object')

# %%
AFRP = Aquadf[['AREA,N,20,5', 'PERIMETER,N,20,5', 'FIRE_,N,11,0', 'FIRE_ID,N,11,0',
       'LAT,N,13,3', 'LONG,N,13,3', 'DATE,D', 'JULIAN,N,3,0', 'GMT,N,4,0', 
       'SPIX,N,6,1', 'TPIX,N,6,1', 'SRC,C,10', 'SAT_SRC,C,1', 'CONF,N,3,0', 
       'FRP,N,8,1']]

# %%
ATemp = Aquadf[['AREA,N,20,5', 'PERIMETER,N,20,5', 'FIRE_,N,11,0', 'FIRE_ID,N,11,0',
       'LAT,N,13,3', 'LONG,N,13,3', 'DATE,D', 'JULIAN,N,3,0', 'GMT,N,4,0',
       'TEMP,N,6,1', 'SPIX,N,6,1', 'TPIX,N,6,1', 'SRC,C,10', 'SAT_SRC,C,1',
       'CONF,N,3,0']]

# %%
TFRP = Terradf[['AREA,N,20,5', 'PERIMETER,N,20,5', 'FIRE_,N,11,0', 'FIRE_ID,N,11,0',
       'LAT,N,13,3', 'LONG,N,13,3', 'DATE,D', 'JULIAN,N,3,0', 'GMT,N,4,0',
       'SPIX,N,6,1', 'TPIX,N,6,1', 'SRC,C,10', 'SAT_SRC,C,1',
       'CONF,N,3,0', 'FRP,N,8,1']]

# %%
TTemp = Terradf[['AREA,N,20,5', 'PERIMETER,N,20,5', 'FIRE_,N,11,0', 'FIRE_ID,N,11,0',
       'LAT,N,13,3', 'LONG,N,13,3', 'DATE,D', 'JULIAN,N,3,0', 'GMT,N,4,0',
       'TEMP,N,6,1', 'SPIX,N,6,1', 'TPIX,N,6,1', 'SRC,C,10', 'SAT_SRC,C,1',
       'CONF,N,3,0']]

# %%
AFRP.to_excel('AFRP_2018.xlsx')

# %%
ATemp.to_excel('ATemp_2018.xlsx')

# %%
TFRP.to_excel('TFRP_2018.xlsx')

# %%
TTemp.to_excel('TTemp_2018.xlsx')
